# %% [markdown]
# # PI
#
#
# ```{image} yl.png
# :width: 250px
# :align: left
# ```
# ## Yongtao Liu, Ph.D.
#
# [Email: liuy3@ornl.gov](liuy3@ornl.gov)
#
# [ORNLWeb](https://www.ornl.gov/staff-profile/yongtao-liu)
#
# [Google Scholar](https://scholar.google.com/citations?user=V9FMPgQAAAAJ&hl=en)
#
# [LinkedIn](https://www.linkedin.com/in/yong-tao-liu/)
#
#
#
# ---
# ### Bio
# Dr. Yongtao Liu is an R&D staff member at the Center for Nanophase Materials Sciences (CNMS) at Oak Ridge National Laboratory (ORNL). Dr. Liu’s current work focuses on integrating artificial intelligence (AI) with physics to develop autonomous experimentation platforms that accelerate progress in materials science. He is engaged in interdisciplinary projects and is committed to fostering synergy between human expertise and AI, he strives to develop innovative tools and methods that empower researchers worldwide. Dr. Liu’s research interests also include functional materials, such as ferroelectric, optoelectronic, and photovoltaic materials.
#
# ### Education
# Ph.D. — The University of Tennessee, Knoxville, TN, USA
#
# B.S. — Nankai University, Tianjin, China
#
# ---
#
# ```{image} hai.png
# :width: 200px
# :align: right
# ```
# ```{image} cfae.png
# :width: 200px
# :align: right
# ```
# ```{image} iai.png
# :width: 200px
# :align: right
# ```
# ### Research Interest
#
# - Autonomous Scientific Discovery: Designing AI-powered autonomous experimentation frameworks to accelerate materials research and uncover novel phenomena.
#
#
# - Human-AI Collaboration: Integrating domain expertise with artificial intelligence to guide, interpret, and refine autonomous experiments for faster and more insightful scientific discovery.
#
#
# - Cross-Facility Autonomous Experiment: Developing interconnected autonomous experimentation platforms to enable real-time, collaborative optimization across distributed research facilities.
#
#
# - Interpretable Machine Learning for Science: Creating transparent, explainable AI models to drive hypothesis generation and mechanistic understanding in materials science.
#
#
# - Functional Materials at the Nanoscale: Exploring the nanoscale behavior of functional materials, such as ferroelectrics, halide perovskite optoelectronics, and semiconducting polymers, through advanced imaging and spectroscopy characterization techniques.
#
#
# ---
#
# ### Professional and Synergistic Activities
# - 2025 – 2026: Associate Editor (Guest), npj Flexible Electronics
# - 2025-present: Board Members of Materials Research Society (MRS) Artificial Intelligence
# (AI) Topical Community.
# - 2024 - 2025: Executive Committee Member of American Vacuum Society (AVS)
# Nanoscale Science and Technology Division (NSTD)
