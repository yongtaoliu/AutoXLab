# %% [markdown]
# ```{image} autoxlab.png
# :width: 700px
# :align: center
# ```
# ---
#
# Welcome to AutoXLab, where AI-driven exploration and experimentation redefine the boundaries of scientific discovery. At the intersection of autonomous experimentation, interpretable machine learning, and human-AI collaboration, AutoXLab develops next-generation platforms that accelerate materials innovation and uncover new phenomena. Explore how we integrate domain expertise with artificial intelligence to empower intelligent experimentation across scales and facilities.
#
# At the core of AutoXLab’s domain research is achieving empirical multiscale correlation through autonomous experimentation and AI, decoding how atomic-scale phenomena dictate macro-scale performance — a challenge central to functional materials, batteries, and advanced structural alloys. By deploying autonomous closed-loop workflows, we bridge these disparate physical scales, utilizing AI to track dynamic processes like phase transitions in solid-state electrolytes, quantum state emergences in functional compounds, and microstructural evolution in high-entropy alloys. Rather than relying on brute-force automation, our platform integrates interpretable AI and agentic AI reasoning with operando characterization and high-throughput synthesis. This synergy allows us to extract the underlying physical and chemical laws governing material behavior, transforming massive multi-scale data streams into actionable insights that accelerate the discovery of materials.
